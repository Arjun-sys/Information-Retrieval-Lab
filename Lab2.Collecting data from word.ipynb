# %%
# !pip install python-docx
# Out:
# ...
#   Created wheel for python-docx: filename=python_docx-0.8.11-py3-none-any.whl size=184606 sha256=5c0f26f618e6bffa21677f9c83cdff2ecea08fbf142fe6820ed625f46fedb6a4
#   Stored in directory: c:\users\admin\appdata\local\pip\cache\wheels\32\b8\b2\c4c2b95765e615fe139b0b17b5ea7c0e1b6519b0a9ec8fb34d
# Successfully built python-docx
# ...

# %%
from docx import Document

# %%
def get_data_from_word(path_to_file):
   
#creating a word file object
    doc_object=open(path_to_file,"rb")
   
#creating word reader object
    doc_reader=Document(doc_object)
    data=""
    for p in doc_reader.paragraphs:
        data +=p.text+"\n"
        
    return data

# %%
word_file=get_data_from_word("./downloads/correct.docx")

# %%
print(word_file)
# Out:
# Scope:
#  Online Nagarpalika, where Certificate Distribution is a vital task of any Municipality so as its name define or verify this has a wide scope or cover wide aspect in current time. Some of the scope related to this field are listed below:
# i.Time Management: we can access services quickly without any delay until and unless some network issues.
# ii. Cost-effective: No need to travel to a physical location to get the work done. We can get our work completed in small time without traveling. Instead, the same service can be accessed at a much lower cost than usual.
# iii. Transparency: With the digitization of every piece of work and process, there is no place left for corruption or any biases. There is equality and a good relationship with every citizen.
# ...
